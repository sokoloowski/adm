# %% [markdown]
# # Advanced Data Mining
#
# ## Models learning
#
# ### Classification with Linear Support Vector Classification

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.svm import LinearSVC

from scripts.classification import train_analyze
from scripts.colors import bold
from scripts.utils import checkpoint
# Out:
# Matplotlib created a temporary cache directory at /tmp/matplotlib-q70yd2n9 because the default path (/.config/matplotlib) is not a writable directory; it is highly recommended to set the MPLCONFIGDIR environment variable to a writable directory, in particular to speed up the import of Matplotlib and to better support multiprocessing.

# %% [markdown]
# Load data from previous step

# %%
df = checkpoint("03-cleaned")

rows, cols = df.shape
print("Dataframe contains", bold(f"{rows} rows"), "and", bold(f"{cols} columns"))
# Out:
# Dataframe contains 19932 rows and 21 columns

# %% [markdown]
# #### Bag of words
#
# Analyze each loss available for `LinearSVC` class

# %% [markdown]
# ##### `squared_hinge` loss

# %%
train_analyze(LinearSVC(loss='squared_hinge', max_iter=10000),
              CountVectorizer(), df)
# Out:
# Training took 474.88 seconds
# First 10 predictions for LinearSVC with squared_hinge on CountVectorizer:
# 	 technology -> gaming
# 	 gaming -> gaming
# 	 programming -> programming
# 	 technology -> technology
# 	 technology -> technology
# 	 programming -> programming
# 	 science -> science
# 	 politics -> politics
# 	 science -> science
# 	 politics -> politics
#
# Classification report for LinearSVC with squared_hinge on CountVectorizer:
#               precision    recall  f1-score   support
#
#       gaming       0.74      0.77      0.76       935
#     politics       0.67      0.69      0.68       997
#  programming       0.76      0.74      0.75      1017
#      science       0.71      0.68      0.69      1040
#   technology       0.54      0.53      0.54       994
#
#     accuracy                           0.68      4983
#    macro avg       0.68      0.68      0.68      4983
# weighted avg       0.68      0.68      0.68      4983

# %% [markdown]
# ##### `hinge` loss

# %%
train_analyze(LinearSVC(loss='hinge', max_iter=10000),
              CountVectorizer(), df)
# Out:
# Training took 12.27 seconds
# First 10 predictions for LinearSVC with hinge on CountVectorizer:
# 	 science -> programming
# 	 programming -> programming
# 	 programming -> politics
# 	 technology -> technology
# 	 gaming -> science
# 	 science -> science
# 	 politics -> politics
# 	 programming -> programming
# 	 technology -> programming
# 	 programming -> technology
#
# Classification report for LinearSVC with hinge on CountVectorizer:
#               precision    recall  f1-score   support
#
#       gaming       0.73      0.76      0.75       986
#     politics       0.67      0.68      0.67       936
#  programming       0.75      0.74      0.74       993
#      science       0.69      0.64      0.67      1060
#   technology       0.53      0.54      0.53      1008
#
#     accuracy                           0.67      4983
#    macro avg       0.67      0.67      0.67      4983
# weighted avg       0.67      0.67      0.67      4983

# %% [markdown]
# #### *tf-idf*
#
# Analyze each loss available for `LinearSVC` class

# %% [markdown]
# ##### `squared_hinge` loss

# %%
train_analyze(LinearSVC(loss='squared_hinge', max_iter=10000),
              TfidfVectorizer(), df)
# Out:
# Training took 2.5 seconds
# First 10 predictions for LinearSVC with squared_hinge on TfidfVectorizer:
# 	 politics -> politics
# 	 technology -> politics
# 	 science -> politics
# 	 programming -> programming
# 	 programming -> programming
# 	 technology -> technology
# 	 gaming -> technology
# 	 science -> science
# 	 politics -> politics
# 	 technology -> politics
#
# Classification report for LinearSVC with squared_hinge on TfidfVectorizer:
#               precision    recall  f1-score   support
#
#       gaming       0.85      0.83      0.84       951
#     politics       0.75      0.79      0.77      1032
#  programming       0.81      0.82      0.82      1004
#      science       0.75      0.77      0.76       987
#   technology       0.65      0.61      0.63      1009
#
#     accuracy                           0.76      4983
#    macro avg       0.76      0.76      0.76      4983
# weighted avg       0.76      0.76      0.76      4983

# %% [markdown]
# ##### `hinge` loss

# %%
train_analyze(LinearSVC(loss='hinge', max_iter=10000),
              TfidfVectorizer(), df)
# Out:
# Training took 1.05 seconds
# First 10 predictions for LinearSVC with hinge on TfidfVectorizer:
# 	 politics -> politics
# 	 technology -> technology
# 	 programming -> programming
# 	 science -> science
# 	 politics -> politics
# 	 technology -> programming
# 	 politics -> programming
# 	 politics -> politics
# 	 science -> science
# 	 science -> science
#
# Classification report for LinearSVC with hinge on TfidfVectorizer:
#               precision    recall  f1-score   support
#
#       gaming       0.87      0.84      0.86       968
#     politics       0.76      0.82      0.79      1076
#  programming       0.84      0.81      0.83       986
#      science       0.75      0.80      0.77       996
#   technology       0.70      0.63      0.66       957
#
#     accuracy                           0.78      4983
#    macro avg       0.78      0.78      0.78      4983
# weighted avg       0.78      0.78      0.78      4983

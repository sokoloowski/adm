# %% [markdown]
# # Advanced Data Mining
#
# ## Models learning
#
# ### Classification with Dense Neural Networks

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
import tensorflow as tf

# %%
tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
tf.__version__
# Out:
# '2.14.0'

# %%
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2022 NVIDIA Corporation
# Built on Wed_Sep_21_10:33:58_PDT_2022
# Cuda compilation tools, release 11.8, V11.8.89
# Build cuda_11.8.r11.8/compiler.31833905_0

# %%
# !nvidia-smi
# Out:
# Mon Dec 16 17:16:41 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.183.01             Driver Version: 535.183.01   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA GeForce RTX 3090        Off | 00000000:21:00.0 Off |                  N/A |
# |  0%   53C    P0             105W / 350W |      3MiB / 24576MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %% [markdown]
# # Data loading

# %%
data = pd.read_csv('data/subreddit_body.csv')

# %%
df = data[['body', 'subreddit']]

# %%
df.head()
# Out:
#                                                 body   subreddit
# 0  oh morality law work u think exists fed basica...  technology
# 1  sign contract agree really good deal compare o...  technology
# 2  logic equivalent people sell gun ammo responsi...  technology
# 3  sure could go four core like competition seem ...  technology
# 4  near term hydrogen simply n t compete alternat...  technology

# %%
df.subreddit.value_counts()
# Out:
# subreddit
# politics       9993
# science        9985
# programming    9981
# technology     9974
# gaming         9885
# Name: count, dtype: int64

# %%
df = pd.concat([df[df['subreddit'] == subreddit].sample(9000, random_state=42)
                for subreddit in df['subreddit'].unique()]).reset_index(drop=True)
df['subreddit'].value_counts()
# Out:
# subreddit
# technology     9000
# politics       9000
# science        9000
# gaming         9000
# programming    9000
# Name: count, dtype: int64

# %% [markdown]
# # Word2Vev

# %%
import os

os.environ['GENSIM_DATA_DIR'] = '/tf/embedding'

# %%
import gensim.downloader as api
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense, Dropout
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.preprocessing import LabelEncoder

print("Loading pre-trained Word2Vec model...")
word2vec = api.load("word2vec-google-news-300")

text_data = df['body'].values

label_encoder = LabelEncoder()
y = label_encoder.fit_transform(df['subreddit'])
labels = y

tokenizer = Tokenizer()
tokenizer.fit_on_texts(text_data)
word_index = tokenizer.word_index
sequences = tokenizer.texts_to_sequences(text_data)
padded_sequences = pad_sequences(sequences, padding='post')

vocab_size = len(word_index) + 1
embedding_dim = word2vec.vector_size
embedding_matrix = np.zeros((vocab_size, embedding_dim))

for word, i in word_index.items():
    if word in word2vec.key_to_index:
        embedding_matrix[i] = word2vec[word]
# Out:
# Loading pre-trained Word2Vec model...

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(padded_sequences, labels, test_size=0.2, random_state=42)

# %% [markdown]
# # Dense Model

# %%
model = Sequential([
    Embedding(input_dim=vocab_size,
              output_dim=embedding_dim,
              weights=[embedding_matrix],
              input_length=padded_sequences.shape[1],
              trainable=False),
    tf.keras.layers.GlobalAveragePooling1D(),
    Dense(32, activation='relu'),
    Dropout(0.3),
    Dense(32, activation='relu'),
    Dropout(0.3),
    Dense(16, activation='relu'),
    Dropout(0.3),
    Dense(5, activation='softmax')  # 5 neurons for 5 classes
])

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

print(model.summary())

history = model.fit(X_train, y_train,
                    epochs=50, batch_size=128, validation_split=0.1, verbose=1)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 1072, 300)         7788900
#
#  global_average_pooling1d (G  (None, 300)              0
#  lobalAveragePooling1D)
#
#  dense (Dense)               (None, 32)                9632
#
#  dropout (Dropout)           (None, 32)                0
#
#  dense_1 (Dense)             (None, 32)                1056
#
#  dropout_1 (Dropout)         (None, 32)                0
#
#  dense_2 (Dense)             (None, 16)                528
#
#  dropout_2 (Dropout)         (None, 16)                0
#
#  dense_3 (Dense)             (None, 5)                 85
#
# =================================================================
# Total params: 7,800,201
# Trainable params: 11,301
# Non-trainable params: 7,788,900
# _________________________________________________________________
# None
# Epoch 1/50
# 254/254 [==============================] - 9s 7ms/step - loss: 1.4586 - accuracy: 0.3239 - val_loss: 1.2607 - val_accuracy: 0.4958
# Epoch 2/50
# 254/254 [==============================] - 1s 5ms/step - loss: 1.2555 - accuracy: 0.4439 - val_loss: 1.1408 - val_accuracy: 0.6411
# Epoch 3/50
# 254/254 [==============================] - 1s 5ms/step - loss: 1.1374 - accuracy: 0.5500 - val_loss: 0.9985 - val_accuracy: 0.6506
# Epoch 4/50
# 254/254 [==============================] - 1s 5ms/step - loss: 1.0553 - accuracy: 0.6102 - val_loss: 0.9148 - val_accuracy: 0.6875
# Epoch 5/50
# 254/254 [==============================] - 1s 5ms/step - loss: 0.9976 - accuracy: 0.6453 - val_loss: 0.8951 - val_accuracy: 0.6975
# Epoch 6/50
# 254/254 [==============================] - 1s 5ms/step - loss: 0.9682 - accuracy: 0.6646 - val_loss: 0.8743 - val_accuracy: 0.7139
# Epoch 7/50
# 254/254 [==============================] - 1s 5ms/step - loss: 0.9456 - accuracy: 0.6788 - val_loss: 0.8519 - val_accuracy: 0.7267
# Epoch 8/50
# 254/254 [==============================] - 1s 5ms/step - loss: 0.9306 - accuracy: 0.6865 - val_loss: 0.8540 - val_accuracy: 0.7194
# Epoch 9/50
# 254/254 [==============================] - 1s 5ms/step - loss: 0.9177 - accuracy: 0.6929 - val_loss: 0.8293 - val_accuracy: 0.7339
# Epoch 10/50
# 254/254 [==============================] - 1s 5ms/step - loss: 0.9159 - accuracy: 0.6970 - val_loss: 0.8314 - val_accuracy: 0.7392
# Epoch 11/50
# 254/254 [==============================] - 1s 5ms/step - loss: 0.9039 - accuracy: 0.7004 - val_loss: 0.8424 - val_accuracy: 0.7275
# Epoch 12/50
# 254/254 [==============================] - 1s 5ms/step - loss: 0.8951 - accuracy: 0.7054 - val_loss: 0.8273 - val_accuracy: 0.7336
# Epoch 13/50
# 254/254 [==============================] - 1s 4ms/step - loss: 0.8898 - accuracy: 0.7065 - val_loss: 0.8188 - val_accuracy: 0.7378
# Epoch 14/50
# 254/254 [==============================] - 1s 5ms/step - loss: 0.8896 - accuracy: 0.7068 - val_loss: 0.8135 - val_accuracy: 0.7378
# Epoch 15/50
# 254/254 [==============================] - 1s 5ms/step - loss: 0.8802 - accuracy: 0.7099 - val_loss: 0.8090 - val_accuracy: 0.7406
# Epoch 16/50
# 254/254 [==============================] - 1s 5ms/step - loss: 0.8813 - accuracy: 0.7118 - val_loss: 0.8142 - val_accuracy: 0.7372
# Epoch 17/50
# 254/254 [==============================] - 1s 5ms/step - loss: 0.8754 - accuracy: 0.7152 - val_loss: 0.8062 - val_accuracy: 0.7500
# Epoch 18/50
# 254/254 [==============================] - 1s 5ms/step - loss: 0.8758 - accuracy: 0.7137 - val_loss: 0.8081 - val_accuracy: 0.7447
# Epoch 19/50
# 254/254 [==============================] - 1s 5ms/step - loss: 0.8685 - accuracy: 0.7155 - val_loss: 0.8014 - val_accuracy: 0.7450
# Epoch 20/50
# 254/254 [==============================] - 1s 5ms/step - loss: 0.8659 - accuracy: 0.7173 - val_loss: 0.8037 - val_accuracy: 0.7486
# Epoch 21/50
# 254/254 [==============================] - 1s 5ms/step - loss: 0.8653 - accuracy: 0.7202 - val_loss: 0.8060 - val_accuracy: 0.7483
# Epoch 22/50
# 254/254 [==============================] - 1s 5ms/step - loss: 0.8591 - accuracy: 0.7204 - val_loss: 0.7985 - val_accuracy: 0.7450
# Epoch 23/50
# 254/254 [==============================] - 1s 5ms/step - loss: 0.8559 - accuracy: 0.7200 - val_loss: 0.7894 - val_accuracy: 0.7547
# Epoch 24/50
# 254/254 [==============================] - 1s 5ms/step - loss: 0.8525 - accuracy: 0.7235 - val_loss: 0.7950 - val_accuracy: 0.7533
# Epoch 25/50
# 254/254 [==============================] - 1s 5ms/step - loss: 0.8507 - accuracy: 0.7228 - val_loss: 0.7875 - val_accuracy: 0.7525
# Epoch 26/50
# 254/254 [==============================] - 1s 5ms/step - loss: 0.8476 - accuracy: 0.7257 - val_loss: 0.7813 - val_accuracy: 0.7547
# Epoch 27/50
# 254/254 [==============================] - 1s 4ms/step - loss: 0.8459 - accuracy: 0.7220 - val_loss: 0.7791 - val_accuracy: 0.7556
# Epoch 28/50
# 254/254 [==============================] - 1s 4ms/step - loss: 0.8421 - accuracy: 0.7263 - val_loss: 0.7896 - val_accuracy: 0.7486
# Epoch 29/50
# 254/254 [==============================] - 1s 5ms/step - loss: 0.8370 - accuracy: 0.7289 - val_loss: 0.7810 - val_accuracy: 0.7544
# Epoch 30/50
# 254/254 [==============================] - 1s 5ms/step - loss: 0.8353 - accuracy: 0.7299 - val_loss: 0.7792 - val_accuracy: 0.7497
# Epoch 31/50
# 254/254 [==============================] - 1s 5ms/step - loss: 0.8345 - accuracy: 0.7281 - val_loss: 0.7809 - val_accuracy: 0.7494
# Epoch 32/50
# 254/254 [==============================] - 1s 5ms/step - loss: 0.8321 - accuracy: 0.7282 - val_loss: 0.7665 - val_accuracy: 0.7553
# Epoch 33/50
# 254/254 [==============================] - 1s 5ms/step - loss: 0.8261 - accuracy: 0.7310 - val_loss: 0.7660 - val_accuracy: 0.7586
# Epoch 34/50
# 254/254 [==============================] - 1s 5ms/step - loss: 0.8302 - accuracy: 0.7310 - val_loss: 0.7632 - val_accuracy: 0.7519
# Epoch 35/50
# 254/254 [==============================] - 2s 6ms/step - loss: 0.8150 - accuracy: 0.7334 - val_loss: 0.7556 - val_accuracy: 0.7603
# Epoch 36/50
# 254/254 [==============================] - 1s 5ms/step - loss: 0.8221 - accuracy: 0.7328 - val_loss: 0.7718 - val_accuracy: 0.7542
# Epoch 37/50
# 254/254 [==============================] - 1s 5ms/step - loss: 0.8177 - accuracy: 0.7335 - val_loss: 0.7507 - val_accuracy: 0.7628
# Epoch 38/50
# 254/254 [==============================] - 1s 5ms/step - loss: 0.8204 - accuracy: 0.7344 - val_loss: 0.7635 - val_accuracy: 0.7458
# Epoch 39/50
# 254/254 [==============================] - 1s 5ms/step - loss: 0.8109 - accuracy: 0.7379 - val_loss: 0.7647 - val_accuracy: 0.7503
# Epoch 40/50
# 254/254 [==============================] - 1s 5ms/step - loss: 0.8130 - accuracy: 0.7392 - val_loss: 0.7509 - val_accuracy: 0.7572
# Epoch 41/50
# 254/254 [==============================] - 1s 5ms/step - loss: 0.8074 - accuracy: 0.7374 - val_loss: 0.7524 - val_accuracy: 0.7622
# Epoch 42/50
# 254/254 [==============================] - 1s 5ms/step - loss: 0.8067 - accuracy: 0.7396 - val_loss: 0.7519 - val_accuracy: 0.7625
# Epoch 43/50
# 254/254 [==============================] - 1s 5ms/step - loss: 0.8052 - accuracy: 0.7388 - val_loss: 0.7486 - val_accuracy: 0.7558
# Epoch 44/50
# 254/254 [==============================] - 1s 5ms/step - loss: 0.8053 - accuracy: 0.7415 - val_loss: 0.7523 - val_accuracy: 0.7672
# Epoch 45/50
# 254/254 [==============================] - 1s 5ms/step - loss: 0.8051 - accuracy: 0.7372 - val_loss: 0.7520 - val_accuracy: 0.7542
# Epoch 46/50
# 254/254 [==============================] - 1s 5ms/step - loss: 0.8075 - accuracy: 0.7389 - val_loss: 0.7447 - val_accuracy: 0.7611
# Epoch 47/50
# 254/254 [==============================] - 1s 5ms/step - loss: 0.7981 - accuracy: 0.7402 - val_loss: 0.7527 - val_accuracy: 0.7536
# Epoch 48/50
# 254/254 [==============================] - 1s 5ms/step - loss: 0.8033 - accuracy: 0.7378 - val_loss: 0.7418 - val_accuracy: 0.7564
# Epoch 49/50
# 254/254 [==============================] - 1s 5ms/step - loss: 0.8014 - accuracy: 0.7390 - val_loss: 0.7374 - val_accuracy: 0.7622
# Epoch 50/50
# 254/254 [==============================] - 1s 5ms/step - loss: 0.7953 - accuracy: 0.7407 - val_loss: 0.7573 - val_accuracy: 0.7489

# %%
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label='val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
plt.savefig('report/src/images/dense_accuracy.png')
plt.show()

# %%
loss, accuracy = model.evaluate(X_test, y_test, verbose=0)
print(f"Loss: {loss:.4f}, Accuracy: {accuracy:.4f}")
# Out:
# Loss: 0.7403, Accuracy: 0.7507

# %%
from sklearn.metrics import confusion_matrix

y_pred = model.predict(X_test)
y_pred_classes = np.argmax(y_pred, axis=1)

cm = confusion_matrix(y_test, y_pred_classes)
plt.figure(figsize=(16, 9))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=label_encoder.classes_,
            yticklabels=label_encoder.classes_)
plt.savefig('report/src/images/dense_confusion_matrix.png')
plt.show()
# Out:
# 282/282 [==============================] - 0s 1ms/step

# %%
from sklearn.preprocessing import LabelBinarizer
from sklearn.metrics import roc_curve, auc

labels = label_encoder.classes_

y_score = model.predict(X_test)

# Plot ROC curve
label_binarizer = LabelBinarizer().fit(y_train)
y_onehot_test = label_binarizer.transform(y_test)
limits = [-0.02, 1.02]
plt.figure(figsize=(6, 6))
for i, label in enumerate(labels):
    fpr, tpr, _ = roc_curve(y_onehot_test[:, i], y_score[:, i])
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, label=f'{label} (area = {roc_auc:.2f})')
plt.plot(limits, limits, 'k--')
plt.xlim(limits)
plt.ylim(limits)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend()
plt.title(f'ROC curve for Dense NN')
plt.gca().set_aspect('equal')
plt.savefig(f'report/src/images/roc_dense.png', bbox_inches='tight')
plt.show()
# Out:
# 282/282 [==============================] - 0s 1ms/step

# %% [markdown]
# # LSTM Model

# %%
model = Sequential([
    Embedding(input_dim=vocab_size,
              output_dim=embedding_dim,
              weights=[embedding_matrix],
              input_length=padded_sequences.shape[1],
              trainable=False),
    tf.keras.layers.SpatialDropout1D(0.2),
    tf.keras.layers.Bidirectional(LSTM(128, return_sequences=True)),
    Dropout(0.2),
    tf.keras.layers.Bidirectional(LSTM(64, return_sequences=False)),
    Dropout(0.2),
    Dense(128, activation='relu'),
    Dropout(0.3),
    Dense(64, activation='relu'),
    Dropout(0.3),
    Dense(64, activation='relu'),
    Dropout(0.3),
    Dense(5, activation='softmax')
])

model.compile(optimizer=tf.keras.optimizers.RMSprop(lr=0.00005), loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

print(model.summary())

history = model.fit(X_train, y_train,
                    epochs=20, batch_size=128, validation_split=0.1, verbose=1)
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.RMSprop.
# Model: "sequential_16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_16 (Embedding)    (None, 1072, 300)         7788900
#
#  spatial_dropout1d_16 (Spat  (None, 1072, 300)         0
#  ialDropout1D)
#
#  bidirectional_42 (Bidirect  (None, 1072, 256)         439296
#  ional)
#
#  dropout_83 (Dropout)        (None, 1072, 256)         0
#
#  bidirectional_43 (Bidirect  (None, 128)               164352
#  ional)
#
#  dropout_84 (Dropout)        (None, 128)               0
#
#  dense_57 (Dense)            (None, 128)               16512
#
#  dropout_85 (Dropout)        (None, 128)               0
#
#  dense_58 (Dense)            (None, 64)                8256
#
#  dropout_86 (Dropout)        (None, 64)                0
#
#  dense_59 (Dense)            (None, 64)                4160
#
#  dropout_87 (Dropout)        (None, 64)                0
#
#  dense_60 (Dense)            (None, 5)                 325
#
# =================================================================
# Total params: 8421801 (32.13 MB)
# Trainable params: 632901 (2.41 MB)
# Non-trainable params: 7788900 (29.71 MB)
# _________________________________________________________________
# None
# Epoch 1/20
# 254/254 [==============================] - 47s 168ms/step - loss: 1.2387 - accuracy: 0.5158 - val_loss: 0.9931 - val_accuracy: 0.6250
# Epoch 2/20
# 254/254 [==============================] - 43s 169ms/step - loss: 1.0072 - accuracy: 0.6528 - val_loss: 0.9104 - val_accuracy: 0.6844
# Epoch 3/20
# 254/254 [==============================] - 43s 168ms/step - loss: 0.9316 - accuracy: 0.6881 - val_loss: 1.0459 - val_accuracy: 0.6511
# Epoch 4/20
# 254/254 [==============================] - 43s 168ms/step - loss: 0.9084 - accuracy: 0.6990 - val_loss: 0.8867 - val_accuracy: 0.6919
# Epoch 5/20
# 254/254 [==============================] - 43s 170ms/step - loss: 0.8605 - accuracy: 0.7084 - val_loss: 0.8956 - val_accuracy: 0.6947
# Epoch 6/20
# 254/254 [==============================] - 43s 169ms/step - loss: 0.8396 - accuracy: 0.7196 - val_loss: 0.8390 - val_accuracy: 0.7200
# Epoch 7/20
# 254/254 [==============================] - 43s 168ms/step - loss: 0.8111 - accuracy: 0.7280 - val_loss: 0.8157 - val_accuracy: 0.7214
# Epoch 8/20
# 254/254 [==============================] - 43s 167ms/step - loss: 0.7966 - accuracy: 0.7333 - val_loss: 0.7894 - val_accuracy: 0.7356
# Epoch 9/20
# 254/254 [==============================] - 43s 169ms/step - loss: 0.7827 - accuracy: 0.7376 - val_loss: 0.7335 - val_accuracy: 0.7472
# Epoch 10/20
# 254/254 [==============================] - 43s 169ms/step - loss: 0.7657 - accuracy: 0.7435 - val_loss: 0.7293 - val_accuracy: 0.7556
# Epoch 11/20
# 254/254 [==============================] - 43s 171ms/step - loss: 0.7485 - accuracy: 0.7486 - val_loss: 0.7926 - val_accuracy: 0.7378
# Epoch 12/20
# 254/254 [==============================] - 44s 172ms/step - loss: 0.7374 - accuracy: 0.7509 - val_loss: 0.7779 - val_accuracy: 0.7236
# Epoch 13/20
# 254/254 [==============================] - 43s 169ms/step - loss: 0.7259 - accuracy: 0.7543 - val_loss: 0.7563 - val_accuracy: 0.7492
# Epoch 14/20
# 254/254 [==============================] - 42s 167ms/step - loss: 0.7113 - accuracy: 0.7588 - val_loss: 0.7510 - val_accuracy: 0.7386
# Epoch 15/20
# 254/254 [==============================] - 43s 171ms/step - loss: 0.7039 - accuracy: 0.7593 - val_loss: 0.8091 - val_accuracy: 0.7347
# Epoch 16/20
# 254/254 [==============================] - 42s 166ms/step - loss: 0.6971 - accuracy: 0.7626 - val_loss: 0.7309 - val_accuracy: 0.7606
# Epoch 17/20
# 254/254 [==============================] - 43s 168ms/step - loss: 0.6896 - accuracy: 0.7646 - val_loss: 0.7184 - val_accuracy: 0.7650
# Epoch 18/20
# 254/254 [==============================] - 42s 167ms/step - loss: 0.6792 - accuracy: 0.7679 - val_loss: 0.7018 - val_accuracy: 0.7678
# Epoch 19/20
# 254/254 [==============================] - 42s 167ms/step - loss: 0.6734 - accuracy: 0.7690 - val_loss: 0.6774 - val_accuracy: 0.7733
# Epoch 20/20
# 254/254 [==============================] - 43s 171ms/step - loss: 0.6646 - accuracy: 0.7714 - val_loss: 0.6901 - val_accuracy: 0.7711

# %%
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label='val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
plt.savefig('lstm_accuracy.png')
plt.show()

# %%
# Evaluate the model
loss, accuracy = model.evaluate(X_test, y_test, verbose=0)
print(f"Loss: {loss:.4f}, Accuracy: {accuracy:.4f}")
# Out:
# Loss: 0.6998, Accuracy: 0.7666

# %%
from sklearn.metrics import confusion_matrix

y_pred = model.predict(X_test)
y_pred_classes = np.argmax(y_pred, axis=1)

cm = confusion_matrix(y_test, y_pred_classes)
plt.figure(figsize=(16, 9))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=label_encoder.classes_,
            yticklabels=label_encoder.classes_)
plt.savefig('lstm_confusion_matrix.png')
plt.show()
# Out:
# 282/282 [==============================] - 19s 65ms/step

# %%
# plot roc curve 

from sklearn.preprocessing import LabelBinarizer
from sklearn.metrics import roc_curve, auc

labels = label_encoder.classes_

y_score = model.predict(X_test)

# Plot ROC curve
label_binarizer = LabelBinarizer().fit(y_train)
y_onehot_test = label_binarizer.transform(y_test)
limits = [-0.02, 1.02]
plt.figure(figsize=(6, 6))
for i, label in enumerate(labels):
    fpr, tpr, _ = roc_curve(y_onehot_test[:, i], y_score[:, i])
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, label=f'{label} (area = {roc_auc:.2f})')
plt.plot(limits, limits, 'k--')
plt.xlim(limits)
plt.ylim(limits)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend()
plt.title(f'ROC curve for LSTM NN')
plt.gca().set_aspect('equal')
plt.savefig(f'roc_lstm.png', bbox_inches='tight')
plt.show()
# Out:
# 282/282 [==============================] - 19s 66ms/step

# %% [markdown]
# # LSTM with attention

# %%
import tensorflow as tf
from tensorflow.keras.layers import Layer


class AttentionLayer(Layer):
    def __init__(self, **kwargs):
        super(AttentionLayer, self).__init__(**kwargs)

    def build(self, input_shape):
        self.W = self.add_weight(name='attention_weight',
                                 shape=(input_shape[-1], 1),
                                 initializer='random_normal',
                                 trainable=True)
        self.b = self.add_weight(name='attention_bias',
                                 shape=(1,),
                                 initializer='zeros',
                                 trainable=True)
        super(AttentionLayer, self).build(input_shape)

    def call(self, inputs):
        # Calculate attention scores
        score = tf.nn.tanh(tf.matmul(inputs, self.W) + self.b)
        attention_weights = tf.nn.softmax(score, axis=1)

        # Compute context vector as the weighted sum of inputs
        context_vector = tf.reduce_sum(inputs * attention_weights, axis=1)
        return context_vector

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Embedding(input_dim=vocab_size,
                              output_dim=embedding_dim,
                              weights=[embedding_matrix],
                              input_length=padded_sequences.shape[1],
                              trainable=False),
    tf.keras.layers.SpatialDropout1D(0.2),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(128, return_sequences=True)),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(64, return_sequences=True)),
    tf.keras.layers.Dropout(0.2),
    AttentionLayer(),  # Add the attention layer here
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dropout(0.3),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dropout(0.3),
    tf.keras.layers.Dense(32, activation='relu'),
    tf.keras.layers.Dropout(0.3),
    tf.keras.layers.Dense(5, activation='softmax')
])

model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.00005),
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

print(model.summary())

# Train the model
history = model.fit(X_train, y_train,
                    epochs=30, batch_size=32, validation_split=0.1, verbose=1)
# Out:
# Model: "sequential_17"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_17 (Embedding)    (None, 1072, 300)         7788900
#
#  spatial_dropout1d_17 (Spat  (None, 1072, 300)         0
#  ialDropout1D)
#
#  bidirectional_44 (Bidirect  (None, 1072, 256)         439296
#  ional)
#
#  dropout_88 (Dropout)        (None, 1072, 256)         0
#
#  bidirectional_45 (Bidirect  (None, 1072, 128)         164352
#  ional)
#
#  dropout_89 (Dropout)        (None, 1072, 128)         0
#
#  attention_layer_3 (Attenti  (None, 128)               129
#  onLayer)
#
#  dense_61 (Dense)            (None, 128)               16512
#
#  dropout_90 (Dropout)        (None, 128)               0
#
#  dense_62 (Dense)            (None, 64)                8256
#
#  dropout_91 (Dropout)        (None, 64)                0
#
#  dense_63 (Dense)            (None, 32)                2080
#
#  dropout_92 (Dropout)        (None, 32)                0
#
#  dense_64 (Dense)            (None, 5)                 165
#
# =================================================================
# Total params: 8419690 (32.12 MB)
# Trainable params: 630790 (2.41 MB)
# Non-trainable params: 7788900 (29.71 MB)
# _________________________________________________________________
# None
# Epoch 1/30
# 1013/1013 [==============================] - 163s 155ms/step - loss: 1.3924 - accuracy: 0.4293 - val_loss: 0.9812 - val_accuracy: 0.6869
# Epoch 2/30
# 1013/1013 [==============================] - 154s 152ms/step - loss: 1.0570 - accuracy: 0.6306 - val_loss: 0.8409 - val_accuracy: 0.7181
# Epoch 3/30
# 1013/1013 [==============================] - 152s 150ms/step - loss: 0.9631 - accuracy: 0.6657 - val_loss: 0.7925 - val_accuracy: 0.7333
# Epoch 4/30
# 1013/1013 [==============================] - 151s 149ms/step - loss: 0.9181 - accuracy: 0.6869 - val_loss: 0.7699 - val_accuracy: 0.7419
# Epoch 5/30
# 1013/1013 [==============================] - 153s 151ms/step - loss: 0.8971 - accuracy: 0.6975 - val_loss: 0.7582 - val_accuracy: 0.7472
# Epoch 6/30
# 1013/1013 [==============================] - 156s 154ms/step - loss: 0.8718 - accuracy: 0.7077 - val_loss: 0.7478 - val_accuracy: 0.7464
# Epoch 7/30
# 1013/1013 [==============================] - 151s 149ms/step - loss: 0.8607 - accuracy: 0.7117 - val_loss: 0.7382 - val_accuracy: 0.7453
# Epoch 8/30
# 1013/1013 [==============================] - 154s 152ms/step - loss: 0.8436 - accuracy: 0.7170 - val_loss: 0.7347 - val_accuracy: 0.7519
# Epoch 9/30
# 1013/1013 [==============================] - 157s 155ms/step - loss: 0.8375 - accuracy: 0.7184 - val_loss: 0.7201 - val_accuracy: 0.7528
# Epoch 10/30
# 1013/1013 [==============================] - 160s 158ms/step - loss: 0.8255 - accuracy: 0.7226 - val_loss: 0.7344 - val_accuracy: 0.7419
# Epoch 11/30
# 1013/1013 [==============================] - 158s 156ms/step - loss: 0.8199 - accuracy: 0.7233 - val_loss: 0.7244 - val_accuracy: 0.7506
# Epoch 12/30
# 1013/1013 [==============================] - 155s 153ms/step - loss: 0.8170 - accuracy: 0.7280 - val_loss: 0.7250 - val_accuracy: 0.7475
# Epoch 13/30
# 1013/1013 [==============================] - 159s 157ms/step - loss: 0.8097 - accuracy: 0.7292 - val_loss: 0.7096 - val_accuracy: 0.7592
# Epoch 14/30
# 1013/1013 [==============================] - 153s 151ms/step - loss: 0.7991 - accuracy: 0.7336 - val_loss: 0.7174 - val_accuracy: 0.7481
# Epoch 15/30
# 1013/1013 [==============================] - 153s 151ms/step - loss: 0.8008 - accuracy: 0.7310 - val_loss: 0.7147 - val_accuracy: 0.7533
# Epoch 16/30
# 1013/1013 [==============================] - 152s 150ms/step - loss: 0.7879 - accuracy: 0.7342 - val_loss: 0.7022 - val_accuracy: 0.7600
# Epoch 17/30
# 1013/1013 [==============================] - 155s 153ms/step - loss: 0.7901 - accuracy: 0.7376 - val_loss: 0.6981 - val_accuracy: 0.7556
# Epoch 18/30
# 1013/1013 [==============================] - 158s 156ms/step - loss: 0.7770 - accuracy: 0.7376 - val_loss: 0.7098 - val_accuracy: 0.7503
# Epoch 19/30
# 1013/1013 [==============================] - 157s 155ms/step - loss: 0.7733 - accuracy: 0.7383 - val_loss: 0.6908 - val_accuracy: 0.7625
# Epoch 20/30
# 1013/1013 [==============================] - 161s 159ms/step - loss: 0.7705 - accuracy: 0.7405 - val_loss: 0.6992 - val_accuracy: 0.7581
# Epoch 21/30
# 1013/1013 [==============================] - 163s 161ms/step - loss: 0.7657 - accuracy: 0.7413 - val_loss: 0.6956 - val_accuracy: 0.7578
# Epoch 22/30
# 1013/1013 [==============================] - 164s 162ms/step - loss: 0.7647 - accuracy: 0.7433 - val_loss: 0.7030 - val_accuracy: 0.7500
# Epoch 23/30
# 1013/1013 [==============================] - 163s 161ms/step - loss: 0.7564 - accuracy: 0.7444 - val_loss: 0.6874 - val_accuracy: 0.7653
# Epoch 24/30
# 1013/1013 [==============================] - 163s 161ms/step - loss: 0.7522 - accuracy: 0.7473 - val_loss: 0.6809 - val_accuracy: 0.7681
# Epoch 25/30
# 1013/1013 [==============================] - 164s 162ms/step - loss: 0.7546 - accuracy: 0.7455 - val_loss: 0.6890 - val_accuracy: 0.7644
# Epoch 26/30
# 1013/1013 [==============================] - 163s 161ms/step - loss: 0.7463 - accuracy: 0.7485 - val_loss: 0.6843 - val_accuracy: 0.7644
# Epoch 27/30
# 1013/1013 [==============================] - 164s 162ms/step - loss: 0.7452 - accuracy: 0.7494 - val_loss: 0.6790 - val_accuracy: 0.7689
# Epoch 28/30
# 1013/1013 [==============================] - 164s 162ms/step - loss: 0.7386 - accuracy: 0.7494 - val_loss: 0.6841 - val_accuracy: 0.7664
# Epoch 29/30
# 1013/1013 [==============================] - 163s 161ms/step - loss: 0.7333 - accuracy: 0.7527 - val_loss: 0.6765 - val_accuracy: 0.7725
# Epoch 30/30
# 1013/1013 [==============================] - 163s 160ms/step - loss: 0.7300 - accuracy: 0.7530 - val_loss: 0.6707 - val_accuracy: 0.7742

# %%
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label='val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
plt.savefig('lstm_attention_accuracy.png')
plt.show()

# %%
# Evaluate the model
loss, accuracy = model.evaluate(X_test, y_test, verbose=0)
print(f"Loss: {loss:.4f}, Accuracy: {accuracy:.4f}")
# Out:
# Loss: 0.6728, Accuracy: 0.7671

# %%
from sklearn.metrics import confusion_matrix

y_pred = model.predict(X_test)
y_pred_classes = np.argmax(y_pred, axis=1)

cm = confusion_matrix(y_test, y_pred_classes)
plt.figure(figsize=(16, 9))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=label_encoder.classes_,
            yticklabels=label_encoder.classes_)
plt.savefig('lstm_attention_confusion_matrix.png')
plt.show()
# Out:
# 282/282 [==============================] - 20s 69ms/step

# %%
# plot roc curve 

from sklearn.preprocessing import LabelBinarizer
from sklearn.metrics import roc_curve, auc

labels = label_encoder.classes_

y_score = model.predict(X_test)

# Plot ROC curve
label_binarizer = LabelBinarizer().fit(y_train)
y_onehot_test = label_binarizer.transform(y_test)
limits = [-0.02, 1.02]
plt.figure(figsize=(6, 6))
for i, label in enumerate(labels):
    fpr, tpr, _ = roc_curve(y_onehot_test[:, i], y_score[:, i])
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, label=f'{label} (area = {roc_auc:.2f})')
plt.plot(limits, limits, 'k--')
plt.xlim(limits)
plt.ylim(limits)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend()
plt.title(f'ROC curve for LSTM NN')
plt.gca().set_aspect('equal')
plt.savefig(f'roc_lstm_attention.png', bbox_inches='tight')
plt.show()
# Out:
# 282/282 [==============================] - 20s 70ms/step

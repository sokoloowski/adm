# %% [markdown]
# # Advanced Data Mining
#
# ## Models learning
#
# ### Classification with Logistic Regression with cross-validation

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.linear_model import LogisticRegressionCV

from scripts.classification import train_analyze
from scripts.colors import bold
from scripts.utils import checkpoint

# %% [markdown]
# Load data from previous step

# %%
df = checkpoint("03-cleaned")

rows, cols = df.shape
print("Dataframe contains", bold(f"{rows} rows"), "and", bold(f"{cols} columns"))
# Out:
# Dataframe contains 19933 rows and 21 columns

# %% [markdown]
# #### Bag of words
#
# Analyze each solver available for `LogisticRegressionCV` class

# %% [markdown]
# ##### `lbfgs` solver

# %%
train_analyze(LogisticRegressionCV(solver='lbfgs', max_iter=10000),
              CountVectorizer(), df)
# Out:
# Training took 500.41 seconds
# First 10 predictions for LogisticRegressionCV with lbfgs on CountVectorizer:
# 	 politics -> politics
# 	 science -> science
# 	 programming -> technology
# 	 programming -> programming
# 	 programming -> programming
# 	 technology -> science
# 	 programming -> programming
# 	 technology -> technology
# 	 technology -> technology
# 	 politics -> politics
#
# Classification report for LogisticRegressionCV with lbfgs on CountVectorizer:
#               precision    recall  f1-score   support
#
#       gaming       0.86      0.80      0.83      1044
#     politics       0.72      0.78      0.75       987
#  programming       0.82      0.78      0.80      1001
#      science       0.73      0.81      0.77       972
#   technology       0.63      0.59      0.61       980
#
#     accuracy                           0.75      4984
#    macro avg       0.75      0.75      0.75      4984
# weighted avg       0.75      0.75      0.75      4984

# %% [markdown]
# ##### `newton-cg` solver

# %%
train_analyze(LogisticRegressionCV(solver='newton-cg', max_iter=10000),
              CountVectorizer(), df)
# Out:
# Training took 85.01 seconds
# First 10 predictions for LogisticRegressionCV with newton-cg on CountVectorizer:
# 	 technology -> programming
# 	 programming -> programming
# 	 gaming -> gaming
# 	 programming -> science
# 	 gaming -> gaming
# 	 politics -> politics
# 	 programming -> programming
# 	 science -> science
# 	 politics -> politics
# 	 gaming -> gaming
#
# Classification report for LogisticRegressionCV with newton-cg on CountVectorizer:
#               precision    recall  f1-score   support
#
#       gaming       0.86      0.78      0.82       996
#     politics       0.71      0.79      0.75       999
#  programming       0.82      0.79      0.80      1010
#      science       0.71      0.78      0.74       989
#   technology       0.65      0.59      0.62       990
#
#     accuracy                           0.75      4984
#    macro avg       0.75      0.75      0.75      4984
# weighted avg       0.75      0.75      0.75      4984

# %% [markdown]
# ##### `sag` solver

# %%
train_analyze(LogisticRegressionCV(solver='sag', max_iter=10000),
              CountVectorizer(), df)
# Out:
# Training took 481.01 seconds
# First 10 predictions for LogisticRegressionCV with sag on CountVectorizer:
# 	 gaming -> gaming
# 	 gaming -> gaming
# 	 technology -> technology
# 	 politics -> gaming
# 	 science -> science
# 	 politics -> politics
# 	 technology -> technology
# 	 programming -> programming
# 	 technology -> programming
# 	 science -> science
#
# Classification report for LogisticRegressionCV with sag on CountVectorizer:
#               precision    recall  f1-score   support
#
#       gaming       0.86      0.80      0.83       977
#     politics       0.72      0.79      0.75      1017
#  programming       0.80      0.78      0.79       966
#      science       0.72      0.79      0.75       975
#   technology       0.67      0.61      0.64      1049
#
#     accuracy                           0.75      4984
#    macro avg       0.75      0.75      0.75      4984
# weighted avg       0.75      0.75      0.75      4984

# %% [markdown]
# ##### `saga` solver

# %%
train_analyze(LogisticRegressionCV(solver='saga', max_iter=10000),
              CountVectorizer(), df)
# Out:
# Training took 505.43 seconds
# First 10 predictions for LogisticRegressionCV with saga on CountVectorizer:
# 	 politics -> politics
# 	 programming -> programming
# 	 science -> science
# 	 politics -> politics
# 	 programming -> programming
# 	 gaming -> programming
# 	 technology -> technology
# 	 programming -> science
# 	 science -> science
# 	 technology -> technology
#
# Classification report for LogisticRegressionCV with saga on CountVectorizer:
#               precision    recall  f1-score   support
#
#       gaming       0.86      0.77      0.81       983
#     politics       0.75      0.78      0.76      1013
#  programming       0.80      0.78      0.79      1027
#      science       0.71      0.79      0.75       969
#   technology       0.60      0.58      0.59       992
#
#     accuracy                           0.74      4984
#    macro avg       0.74      0.74      0.74      4984
# weighted avg       0.74      0.74      0.74      4984

# %% [markdown]
# #### *tf-idf*
#
# Analyze each solver available for `LogisticRegressionCV` class

# %% [markdown]
# ##### `lbfgs` solver

# %%
train_analyze(LogisticRegressionCV(solver='lbfgs', max_iter=10000),
              TfidfVectorizer(), df)
# Out:
# Training took 208.25 seconds
# First 10 predictions for LogisticRegressionCV with lbfgs on TfidfVectorizer:
# 	 science -> science
# 	 science -> science
# 	 technology -> technology
# 	 technology -> politics
# 	 politics -> politics
# 	 politics -> politics
# 	 technology -> technology
# 	 science -> science
# 	 technology -> politics
# 	 technology -> politics
#
# Classification report for LogisticRegressionCV with lbfgs on TfidfVectorizer:
#               precision    recall  f1-score   support
#
#       gaming       0.89      0.77      0.83       996
#     politics       0.74      0.81      0.78      1024
#  programming       0.82      0.79      0.81       955
#      science       0.72      0.81      0.77      1034
#   technology       0.65      0.61      0.63       975
#
#     accuracy                           0.76      4984
#    macro avg       0.77      0.76      0.76      4984
# weighted avg       0.77      0.76      0.76      4984

# %% [markdown]
# ##### `newton-cg` solver

# %%
train_analyze(LogisticRegressionCV(solver='newton-cg', max_iter=10000),
              TfidfVectorizer(), df)
# Out:
# Training took 19.71 seconds
# First 10 predictions for LogisticRegressionCV with newton-cg on TfidfVectorizer:
# 	 gaming -> gaming
# 	 science -> science
# 	 gaming -> politics
# 	 programming -> programming
# 	 technology -> technology
# 	 technology -> technology
# 	 science -> science
# 	 programming -> programming
# 	 politics -> politics
# 	 programming -> programming
#
# Classification report for LogisticRegressionCV with newton-cg on TfidfVectorizer:
#               precision    recall  f1-score   support
#
#       gaming       0.89      0.79      0.83      1012
#     politics       0.73      0.83      0.78       992
#  programming       0.87      0.79      0.83      1018
#      science       0.70      0.82      0.76       969
#   technology       0.67      0.61      0.64       993
#
#     accuracy                           0.77      4984
#    macro avg       0.77      0.77      0.77      4984
# weighted avg       0.77      0.77      0.77      4984

# %% [markdown]
# ##### `sag` solver

# %%
train_analyze(LogisticRegressionCV(solver='sag', max_iter=10000),
              TfidfVectorizer(), df)
# Out:
# Training took 150.78 seconds
# First 10 predictions for LogisticRegressionCV with sag on TfidfVectorizer:
# 	 politics -> politics
# 	 gaming -> gaming
# 	 technology -> technology
# 	 gaming -> gaming
# 	 science -> science
# 	 programming -> programming
# 	 science -> gaming
# 	 technology -> politics
# 	 politics -> politics
# 	 programming -> politics
#
# Classification report for LogisticRegressionCV with sag on TfidfVectorizer:
#               precision    recall  f1-score   support
#
#       gaming       0.89      0.79      0.83       973
#     politics       0.73      0.81      0.77       994
#  programming       0.83      0.78      0.81       962
#      science       0.72      0.81      0.76      1027
#   technology       0.67      0.63      0.64      1028
#
#     accuracy                           0.76      4984
#    macro avg       0.77      0.76      0.76      4984
# weighted avg       0.77      0.76      0.76      4984

# %% [markdown]
# ##### `saga` solver

# %%
train_analyze(LogisticRegressionCV(solver='saga', max_iter=10000),
              TfidfVectorizer(), df)
# Out:
# Training took 175.69 seconds
# First 10 predictions for LogisticRegressionCV with saga on TfidfVectorizer:
# 	 politics -> politics
# 	 science -> science
# 	 politics -> politics
# 	 technology -> gaming
# 	 science -> science
# 	 science -> science
# 	 programming -> programming
# 	 gaming -> gaming
# 	 gaming -> technology
# 	 gaming -> gaming
#
# Classification report for LogisticRegressionCV with saga on TfidfVectorizer:
#               precision    recall  f1-score   support
#
#       gaming       0.87      0.78      0.82       982
#     politics       0.73      0.80      0.76      1055
#  programming       0.85      0.81      0.83       981
#      science       0.73      0.81      0.77       987
#   technology       0.65      0.60      0.63       979
#
#     accuracy                           0.76      4984
#    macro avg       0.76      0.76      0.76      4984
# weighted avg       0.76      0.76      0.76      4984

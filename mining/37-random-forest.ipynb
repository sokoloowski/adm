# %% [markdown]
# # Advanced Data Mining
#
# ## Models learning
#
# ### Classification with Random Forest

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.ensemble import RandomForestClassifier

from scripts.classification import train_analyze
from scripts.colors import bold
from scripts.utils import checkpoint

# %% [markdown]
# Load data from previous step

# %%
df = checkpoint("03-cleaned")

rows, cols = df.shape
print("Dataframe contains", bold(f"{rows} rows"), "and", bold(f"{cols} columns"))
# Out:
# Dataframe contains 19933 rows and 21 columns

# %% [markdown]
# #### Bag of words
#
# Analyze each criterion available for `RandomForestClassifier` class

# %% [markdown]
# ##### `gini` criterion

# %%
train_analyze(RandomForestClassifier(criterion='gini', n_jobs=-1),
              CountVectorizer(), df)
# Out:
# Training took 8.95 seconds
# First 10 predictions for RandomForestClassifier with gini on CountVectorizer:
# 	 technology -> politics
# 	 politics -> technology
# 	 programming -> programming
# 	 politics -> politics
# 	 technology -> programming
# 	 science -> politics
# 	 gaming -> gaming
# 	 science -> science
# 	 science -> science
# 	 politics -> politics
#
# Classification report for RandomForestClassifier with gini on CountVectorizer:
#               precision    recall  f1-score   support
#
#       gaming       0.81      0.81      0.81       979
#     politics       0.72      0.79      0.75      1028
#  programming       0.79      0.79      0.79       999
#      science       0.69      0.81      0.74       977
#   technology       0.67      0.49      0.57      1001
#
#     accuracy                           0.74      4984
#    macro avg       0.73      0.74      0.73      4984
# weighted avg       0.73      0.74      0.73      4984

# %% [markdown]
# ##### `entropy` criterion

# %%
train_analyze(RandomForestClassifier(criterion='entropy', n_jobs=-1),
              CountVectorizer(), df)
# Out:
# Training took 11.43 seconds
# First 10 predictions for RandomForestClassifier with entropy on CountVectorizer:
# 	 gaming -> gaming
# 	 gaming -> gaming
# 	 programming -> programming
# 	 programming -> programming
# 	 programming -> programming
# 	 politics -> politics
# 	 technology -> politics
# 	 science -> science
# 	 science -> science
# 	 programming -> science
#
# Classification report for RandomForestClassifier with entropy on CountVectorizer:
#               precision    recall  f1-score   support
#
#       gaming       0.81      0.81      0.81      1004
#     politics       0.68      0.82      0.74      1007
#  programming       0.78      0.78      0.78       994
#      science       0.72      0.78      0.75       969
#   technology       0.67      0.47      0.56      1010
#
#     accuracy                           0.73      4984
#    macro avg       0.73      0.73      0.73      4984
# weighted avg       0.73      0.73      0.73      4984

# %% [markdown]
# ##### `log_loss` criterion

# %%
train_analyze(RandomForestClassifier(criterion='log_loss', n_jobs=-1),
              CountVectorizer(), df)
# Out:
# Training took 10.25 seconds
# First 10 predictions for RandomForestClassifier with log_loss on CountVectorizer:
# 	 science -> science
# 	 technology -> programming
# 	 science -> science
# 	 science -> politics
# 	 technology -> politics
# 	 programming -> technology
# 	 programming -> programming
# 	 science -> science
# 	 science -> gaming
# 	 politics -> science
#
# Classification report for RandomForestClassifier with log_loss on CountVectorizer:
#               precision    recall  f1-score   support
#
#       gaming       0.78      0.79      0.79       981
#     politics       0.68      0.82      0.74       982
#  programming       0.78      0.78      0.78      1025
#      science       0.69      0.76      0.72       978
#   technology       0.67      0.47      0.55      1018
#
#     accuracy                           0.72      4984
#    macro avg       0.72      0.72      0.72      4984
# weighted avg       0.72      0.72      0.72      4984

# %% [markdown]
# #### *tf-idf*
#
# Analyze each criterion available for `RandomForestClassifier` class

# %% [markdown]
# ##### `gini` criterion

# %%
train_analyze(RandomForestClassifier(criterion='gini', n_jobs=-1),
              TfidfVectorizer(), df)
# Out:
# Training took 8.82 seconds
# First 10 predictions for RandomForestClassifier with gini on TfidfVectorizer:
# 	 programming -> programming
# 	 technology -> technology
# 	 programming -> programming
# 	 science -> technology
# 	 programming -> programming
# 	 politics -> politics
# 	 science -> technology
# 	 technology -> programming
# 	 science -> science
# 	 gaming -> gaming
#
# Classification report for RandomForestClassifier with gini on TfidfVectorizer:
#               precision    recall  f1-score   support
#
#       gaming       0.81      0.81      0.81       989
#     politics       0.69      0.79      0.74      1034
#  programming       0.76      0.79      0.78       937
#      science       0.72      0.78      0.75      1033
#   technology       0.66      0.47      0.55       991
#
#     accuracy                           0.73      4984
#    macro avg       0.73      0.73      0.72      4984
# weighted avg       0.73      0.73      0.72      4984

# %% [markdown]
# ##### `entropy` criterion

# %%
train_analyze(RandomForestClassifier(criterion='entropy', n_jobs=-1),
              TfidfVectorizer(), df)
# Out:
# Training took 7.89 seconds
# First 10 predictions for RandomForestClassifier with entropy on TfidfVectorizer:
# 	 gaming -> gaming
# 	 science -> science
# 	 politics -> politics
# 	 technology -> science
# 	 gaming -> gaming
# 	 technology -> politics
# 	 politics -> politics
# 	 programming -> science
# 	 politics -> politics
# 	 science -> programming
#
# Classification report for RandomForestClassifier with entropy on TfidfVectorizer:
#               precision    recall  f1-score   support
#
#       gaming       0.81      0.78      0.79      1009
#     politics       0.64      0.80      0.71       958
#  programming       0.77      0.77      0.77       999
#      science       0.70      0.75      0.72      1025
#   technology       0.65      0.47      0.54       993
#
#     accuracy                           0.71      4984
#    macro avg       0.71      0.71      0.71      4984
# weighted avg       0.71      0.71      0.71      4984

# %% [markdown]
# ##### `log_loss` criterion

# %%
train_analyze(RandomForestClassifier(criterion='log_loss', n_jobs=-1),
              TfidfVectorizer(), df)
# Out:
# Training took 8.77 seconds
# First 10 predictions for RandomForestClassifier with log_loss on TfidfVectorizer:
# 	 gaming -> gaming
# 	 science -> science
# 	 science -> science
# 	 science -> gaming
# 	 politics -> politics
# 	 programming -> politics
# 	 technology -> technology
# 	 technology -> politics
# 	 science -> science
# 	 science -> programming
#
# Classification report for RandomForestClassifier with log_loss on TfidfVectorizer:
#               precision    recall  f1-score   support
#
#       gaming       0.82      0.79      0.81      1060
#     politics       0.67      0.79      0.72       975
#  programming       0.78      0.79      0.78       974
#      science       0.70      0.78      0.74      1019
#   technology       0.63      0.45      0.52       956
#
#     accuracy                           0.72      4984
#    macro avg       0.72      0.72      0.71      4984
# weighted avg       0.72      0.72      0.72      4984

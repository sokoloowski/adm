# %% [markdown]
# # Advanced Data Mining
#
# ## Models learning
#
# ### Classification with Decision Tree

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.ensemble import RandomForestClassifier

from scripts.classification import train_analyze
from scripts.colors import bold
from scripts.utils import checkpoint
# Out:
# Matplotlib created a temporary cache directory at /tmp/matplotlib-5dftt38v because the default path (/.config/matplotlib) is not a writable directory; it is highly recommended to set the MPLCONFIGDIR environment variable to a writable directory, in particular to speed up the import of Matplotlib and to better support multiprocessing.

# %% [markdown]
# Load data from previous step

# %%
df = checkpoint("03-cleaned")

rows, cols = df.shape
print("Dataframe contains", bold(f"{rows} rows"), "and", bold(f"{cols} columns"))
# Out:
# Dataframe contains 19932 rows and 21 columns

# %% [markdown]
# #### Bag of words
#
# Analyze each criterion available for `RandomForestClassifier` class

# %% [markdown]
# ##### `gini` criterion

# %%
train_analyze(RandomForestClassifier(criterion='gini', n_jobs=-1),
              CountVectorizer(), df)
# Out:
# Training took 2.8 seconds
# First 10 predictions for RandomForestClassifier with gini on CountVectorizer:
# 	 programming -> gaming
# 	 technology -> technology
# 	 programming -> programming
# 	 gaming -> gaming
# 	 programming -> programming
# 	 programming -> programming
# 	 science -> science
# 	 gaming -> gaming
# 	 gaming -> gaming
# 	 science -> gaming
#
# Classification report for RandomForestClassifier with gini on CountVectorizer:
#               precision    recall  f1-score   support
#
#       gaming       0.85      0.84      0.84       981
#     politics       0.70      0.82      0.76       991
#  programming       0.82      0.80      0.81      1050
#      science       0.70      0.79      0.74       987
#   technology       0.70      0.51      0.59       974
#
#     accuracy                           0.75      4983
#    macro avg       0.75      0.75      0.75      4983
# weighted avg       0.75      0.75      0.75      4983

# %% [markdown]
# ##### `entropy` criterion

# %%
train_analyze(RandomForestClassifier(criterion='entropy', n_jobs=-1),
              CountVectorizer(), df)
# Out:
# Training took 3.28 seconds
# First 10 predictions for RandomForestClassifier with entropy on CountVectorizer:
# 	 politics -> politics
# 	 gaming -> gaming
# 	 politics -> politics
# 	 politics -> politics
# 	 politics -> politics
# 	 science -> science
# 	 programming -> programming
# 	 science -> politics
# 	 politics -> politics
# 	 politics -> politics
#
# Classification report for RandomForestClassifier with entropy on CountVectorizer:
#               precision    recall  f1-score   support
#
#       gaming       0.81      0.82      0.82       963
#     politics       0.67      0.82      0.74       982
#  programming       0.84      0.80      0.82      1050
#      science       0.70      0.78      0.74      1001
#   technology       0.68      0.48      0.56       987
#
#     accuracy                           0.74      4983
#    macro avg       0.74      0.74      0.73      4983
# weighted avg       0.74      0.74      0.74      4983

# %% [markdown]
# ##### `log_loss` criterion

# %%
train_analyze(RandomForestClassifier(criterion='log_loss', n_jobs=-1),
              CountVectorizer(), df)
# Out:
# Training took 3.95 seconds
# First 10 predictions for RandomForestClassifier with log_loss on CountVectorizer:
# 	 programming -> programming
# 	 technology -> programming
# 	 programming -> programming
# 	 gaming -> gaming
# 	 politics -> politics
# 	 technology -> technology
# 	 technology -> science
# 	 gaming -> politics
# 	 science -> science
# 	 programming -> programming
#
# Classification report for RandomForestClassifier with log_loss on CountVectorizer:
#               precision    recall  f1-score   support
#
#       gaming       0.83      0.82      0.83       960
#     politics       0.70      0.80      0.75      1063
#  programming       0.82      0.80      0.81      1011
#      science       0.67      0.80      0.73       968
#   technology       0.68      0.47      0.56       981
#
#     accuracy                           0.74      4983
#    macro avg       0.74      0.74      0.73      4983
# weighted avg       0.74      0.74      0.73      4983

# %% [markdown]
# #### *tf-idf*
#
# Analyze each criterion available for `RandomForestClassifier` class

# %% [markdown]
# ##### `gini` criterion

# %%
train_analyze(RandomForestClassifier(criterion='gini', n_jobs=-1),
              TfidfVectorizer(), df)
# Out:
# Training took 5.48 seconds
# First 10 predictions for RandomForestClassifier with gini on TfidfVectorizer:
# 	 technology -> technology
# 	 politics -> politics
# 	 politics -> politics
# 	 gaming -> gaming
# 	 programming -> programming
# 	 technology -> science
# 	 science -> science
# 	 politics -> politics
# 	 technology -> technology
# 	 technology -> technology
#
# Classification report for RandomForestClassifier with gini on TfidfVectorizer:
#               precision    recall  f1-score   support
#
#       gaming       0.84      0.83      0.84       999
#     politics       0.71      0.83      0.77      1011
#  programming       0.80      0.79      0.80       961
#      science       0.71      0.78      0.74      1013
#   technology       0.67      0.51      0.58       999
#
#     accuracy                           0.75      4983
#    macro avg       0.75      0.75      0.74      4983
# weighted avg       0.74      0.75      0.74      4983

# %% [markdown]
# ##### `entropy` criterion

# %%
train_analyze(RandomForestClassifier(criterion='entropy', n_jobs=-1),
              TfidfVectorizer(), df)
# Out:
# Training took 5.81 seconds
# First 10 predictions for RandomForestClassifier with entropy on TfidfVectorizer:
# 	 gaming -> gaming
# 	 gaming -> gaming
# 	 programming -> programming
# 	 gaming -> gaming
# 	 politics -> politics
# 	 gaming -> science
# 	 politics -> politics
# 	 programming -> programming
# 	 gaming -> gaming
# 	 politics -> politics
#
# Classification report for RandomForestClassifier with entropy on TfidfVectorizer:
#               precision    recall  f1-score   support
#
#       gaming       0.82      0.83      0.82       999
#     politics       0.68      0.82      0.75       991
#  programming       0.80      0.79      0.79       967
#      science       0.69      0.78      0.73       991
#   technology       0.70      0.48      0.57      1035
#
#     accuracy                           0.74      4983
#    macro avg       0.74      0.74      0.73      4983
# weighted avg       0.74      0.74      0.73      4983

# %% [markdown]
# ##### `log_loss` criterion

# %%
train_analyze(RandomForestClassifier(criterion='log_loss', n_jobs=-1),
              TfidfVectorizer(), df)
# Out:
# Training took 5.61 seconds
# First 10 predictions for RandomForestClassifier with log_loss on TfidfVectorizer:
# 	 politics -> politics
# 	 politics -> science
# 	 politics -> politics
# 	 technology -> programming
# 	 technology -> technology
# 	 politics -> politics
# 	 science -> programming
# 	 gaming -> politics
# 	 programming -> programming
# 	 science -> gaming
#
# Classification report for RandomForestClassifier with log_loss on TfidfVectorizer:
#               precision    recall  f1-score   support
#
#       gaming       0.84      0.83      0.83       988
#     politics       0.68      0.80      0.74      1020
#  programming       0.81      0.78      0.80       974
#      science       0.70      0.78      0.74      1012
#   technology       0.67      0.49      0.57       989
#
#     accuracy                           0.74      4983
#    macro avg       0.74      0.74      0.73      4983
# weighted avg       0.74      0.74      0.73      4983
